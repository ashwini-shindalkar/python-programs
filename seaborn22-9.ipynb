# %% [markdown]
# ### 26/08

# %% [markdown]
# ### Data visualization using seaboarn

# %%
# importing the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# loading dataset 
df= sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.species.unique()    ## give the  uniqe species
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.value_counts()    ## give the value of that specices
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.lineplot(x="sepal_length", y="sepal_width",data=df)
plt.show()

# %%
sns.lineplot(x="sepal_length", y="sepal_width",data=df,hue="species")   ### reprasent using line
plt.show()

# %%
# continuous and categorical feature
sns.lineplot(x='sepal_width', y='species', data=df, hue='species')
plt.show()

# %%
sns.lineplot(x='petal_length', y='species', data=df, hue='species',ci=None)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10860\1337424520.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='petal_length', y='species', data=df, hue='species',ci=None)

# %%
## scatter plot
sns.scatterplot(x="sepal_length",y="sepal_width",data=df,hue="species")
plt.title("Scatter plot")
plt.show()                     ## scatter plot reprasent using dot and give raltionship btween two variables

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x="sepal_length",y="sepal_width",data=df)   ##not use of hue="species"
plt.title("Scatter plot")
plt.show()

# %%
sns.barplot(x='species', y='sepal_length', data=df,hue="species")  ## uesd compare  with categarical and numerical data
plt.show()

# %%
sns.countplot(x='species', data=df,hue="species")
plt.show()

# %%
sns.boxplot(x='sepal_width',data=df, )   ## summery of five statistical measure Q1,Q2,Q3,max,min,  outliers
plt.show()

# %%
sns.boxplot(x='species', y='sepal_width', data=df)
plt.show()
# Checking outliers in each category with respect to sepal width.

# %%
sns.violinplot(x='species', y='sepal_width', data=df)
plt.show()

# %%
sns.stripplot(x='species', y='petal_width', data=df)
plt.show()

# %%
sns.histplot(x='petal_width', data=df)   ## histogram
plt.show()

# %%
sns.histplot(x='petal_width', data=df,kde=True)    ###..kde default false
plt.show()

# %%
sns.distplot(df['petal_width'],color="g",hist=False, kde=False)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6188\3611550523.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_width'],color="g",hist=False, kde=False)

# %%
sns.distplot(df['petal_width'],color="g",hist=True, kde=False) ### hist default false
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10860\2121688592.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_width'],color="g",hist=True, kde=False) ### hist default false

# %%
sns.distplot(df['petal_width'],color="g",hist=True, kde=True)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6188\3377704576.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_width'],color="g",hist=True, kde=True)

# %%
sns.distplot(df['petal_width'],color="g",hist=False, kde=True)
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_10860\243265233.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_width'],color="g",hist=False, kde=True)

# %%
##Pairplot
##Pairplot represents pairwise relation across the entire dataframe and supports an 

## additional  argument called hue for categorical separation. 
#What it does basically is create a jointplot between every possible numerical 
##column and takes a while if the dataframe is really huge

sns.pairplot(data=df, hue='species')
plt.show()

# %%
# categorical plot
sns.catplot(x='sepal_length', data=df, kind='violin') #violin can use box
plt.show()

# %%
# categorical plot
sns.catplot(x='sepal_length', data=df) #violin can not use 
plt.show()

# %%
#The default representation of the data in catplot() uses a stripplot
sns.catplot(x='species', y='sepal_length', data=df, kind='swarm')
plt.show()

# %%
#The default representation of the data in catplot() uses a stripplot
sns.catplot(x='species', y='sepal_length', data=df)
plt.show()

# %%
sns.catplot(x='petal_length',y='species',data=df)
plt.show()

# %%
##Heat map
## Heatmap is defined as a graphical representation of data using colors to visualize the value of the matrix.
## In this, to represent more common values or higher activities brighter colors basically reddish colors are used and 
## to represent less common or activity values, darker colors are preferred

# correlation between the different parameters 
tc = df.iloc[:,:-1].corr()
  
tc
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(tc, annot = True)    ###...Imp prasent correlation
plt.show()
